# %% [markdown]
# # NBA Lineup Prediction Project
# **Group 21:** Fahad Hussain, Kevaun Harris, Rajiv Lomada
#
# ## Project Overview
#
# This project aims to predict the fifth player in an NBA lineup based on historical data. Given four players from a home team, five players from an away team, and the season, our model predicts the most likely fifth player to complete the home team's lineup.
#
# ## Table of Contents
# 1. [Dataset Description](#dataset-description)
# 2. [Methodology](#methodology)
# 3. [Feature Engineering](#feature-engineering)
# 4. [Selected Model](#selected-model)
# 5. [Training Process](#training-process)
# 6. [Pre and Post Processing](#pre-and-post-processing)
# 7. [Evaluation](#evaluation)
# 8. [Challenges and Future Work](#challenges-and-future-work)
# 9. [Run Our Code](#run-our-code)
#
#
# ## Dataset Description
#
# The dataset consists of:
# - Training data for NBA game lineups from 2007-2015
# - Test data from 2007-2016 (including a season not in the training data)
# - Each record contains the home team lineup, away team lineup, team names, and season
#
# ## Methodology
#
# Our overall approach follows these steps:

# %%
1. Data loading and preprocessing
2. Roster creation for each team and season
3. Feature encoding (converting categorical variables to numerical)
4. Model training using Random Forest Classifier
5. Prediction and evaluation

# %% [markdown]
# ### Data Loading and Processing

# %%
def load_data(data_dir):
    all_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.csv')]
    df_list = []

    for file in all_files:  # Append all csv files into one dataframe
        df = pd.read_csv(file)
        df_list.append(df)
    df = pd.concat(df_list, ignore_index=True)
    
    # Sort players to ensure consistency
    def sort_players(row):
        home_players = sorted([row[f'home_{i}'] for i in range(5)])
        away_players = sorted([row[f'away_{i}'] for i in range(5)])
        for i in range(5):
            row[f'home_{i}'] = home_players[i]
            row[f'away_{i}'] = away_players[i]
        return row
    
    df = df.apply(sort_players, axis=1)
    
    return df

# %% [markdown]
# This function loads all CSV files from the data directory, combines them into a single DataFrame, and sorts player names for consistency. The sorting is crucial because the original data has no specific order for players, and we need to ensure the model doesn't try to learn non-existent patterns.
#
# ### Roster Creation

# %%
def create_rosters(train_df, test_df=None):
    # Create a roster for each team and season from training data
    roster = train_df.groupby(['home_team', 'season'])[[f'home_{i}' for i in range(5)]].apply(
        lambda x: set(pd.unique(x.values.ravel()))
    ).to_dict()
    
    # Also check away lineups
    for idx, row in train_df.iterrows():
        key = (row['away_team'], row['season'])
        if key not in roster:
            roster[key] = set()
        for i in range(5):
            roster[key].add(row[f'away_{i}'])
    
    # Build 2016 rosters from test data
    if test_df is not None:
        train_seasons = set(train_df['season'].unique())
        test_seasons = set(test_df['season'].unique())
        new_seasons = test_seasons - train_seasons
        
        if new_seasons:
            print(f"Building rosters for new seasons: {new_seasons}")
            new_season_df = test_df[test_df['season'].isin(new_seasons)]
            
            # Extract players from test data
            for idx, row in new_season_df.iterrows():
                # Add home team players
                key = (row['home_team'], row['season'])
                if key not in roster:
                    roster[key] = set()
                for i in range(5):
                    player = row[f'home_{i}']
                    if player != '?':  # Skip unknown players
                        roster[key].add(player)
                
                # Add away team players
                key = (row['away_team'], row['season'])
                if key not in roster:
                    roster[key] = set()
                for i in range(5):
                    roster[key].add(row[f'away_{i}'])
                    
            # Add true fifth player to roster
            if 'true_fifth_player' in new_season_df.columns:
                for idx, row in new_season_df.iterrows():
                    key = (row['home_team'], row['season'])
                    if key in roster and row['true_fifth_player'] != '?':
                        roster[key].add(row['true_fifth_player'])
    return roster

# %% [markdown]
# This function creates team rosters for each season, which are essential for our prediction task. It builds dictionaries where keys are (team, season) tuples and values are sets of players. For 2016 (not in training data), rosters are built using the test data itself.
#
# ## Feature Engineering
#
# The features we input for our model are the following:
#
# 1. **Team Encoding**: Converting team names to numerical values
# 2. **Player Encoding**: Converting player names to numerical values
# 3. **Season Encoding**: Converting seasons to numerical values
# 4. **Player Ordering**: Consistently ordering players to create standardized inputs
# 5. **Recency Weighting**: Applying higher weights to more recent seasons

# %%
# Feature encoding
def encode_features(df, player_encoder, team_encoder, season_encoder):
    df['home_team_encoded'] = team_encoder.transform(df['home_team'])
    df['away_team_encoded'] = team_encoder.transform(df['away_team'])
    df['season_encoded'] = season_encoder.transform(df['season'])
    for i in range(5):
        df[f'home_{i}_encoded'] = player_encoder.transform(df[f'home_{i}'])
        df[f'away_{i}_encoded'] = player_encoder.transform(df[f'away_{i}'])
    return df

# Creating recency weights
df['weight'] = df['season'].apply(lambda x: 1 + 0.2 * max(0, x - 2010))

# %% [markdown]
# Since we were restricted to using the 'outcome' column as our main feature/classifier from the dataset, there was little we could do in terms of engineering more complex features. We attempted this, but it always negatively impacted our accuracy results, as the model would overfit the training data.
#
# ## Selected Model
#
# We selected a Random Forest Classifier for our model.

# %%
# Train Random Forest Classifier
model = RandomForestClassifier(n_estimators=500, max_depth=None, random_state=1, n_jobs=-1)
model.fit(X, y, sample_weight=df['weight'])

# %% [markdown]
# ### Why Random Forest?
#
# 1. **Handles complex relationships**: Can capture non-linear relationships between features
# 2. **Robust to outliers**: Less sensitive to outliers which is important in sports data
# 3. **Feature importance**: Provides insights into which features most impact predictions
# 4. **Ensemble method**: Combines multiple decision trees to reduce overfitting
# 5. **Probabilistic output**: Provides probability estimates for each prediction
#
# Our model was configured with 500 trees and no maximum depth constraint, allowing it to fully capture complex patterns in the data.
#
# ## Training Process
#
# The training process involved these steps:

# %%
# Define features and target
X = df[['home_team_encoded', 'season_encoded', 
    'home_0_encoded', 'home_1_encoded', 'home_2_encoded', 'home_3_encoded', 'home_4_encoded',
    'away_0_encoded', 'away_1_encoded', 'away_2_encoded', 'away_3_encoded', 'away_4_encoded']]
y = df['outcome']

# Create weights based on recency
df['weight'] = df['season'].apply(lambda x: 1 + 0.2 * max(0, x - 2010))

# Train Random Forest Classifier
model = RandomForestClassifier(n_estimators=500, max_depth=None, random_state=1, n_jobs=-1)
model.fit(X, y, sample_weight=df['weight'])

# Save model and encoders
joblib.dump(model, 'saved_files/nba_lineup_model.pkl')
joblib.dump(player_encoder, 'saved_files/player_encoder.pkl')
joblib.dump(team_encoder, 'saved_files/team_encoder.pkl')
joblib.dump(season_encoder, 'saved_files/season_encoder.pkl')

# %% [markdown]
# Key aspects of the training process:
# 1. Using sample weights to emphasize more recent seasons
# 2. Saving both the model and encoders for future use
# 3. Using all available CPU cores (n_jobs=-1) to speed up training
# 4. Setting a random state for reproducibility
#
# ## Pre and Post Processing
#
# ### Preprocessing Steps
# Firstly, we modified our training data to drop all the columns not allowed to be used as features. We also dropped the starting_min feature, as it wasn't insightful/helpful and was impacting our accuracy negatively. Then, we modified our training data to use consistent team abbreviations (some teams had multiple abbreviations due to relocations) and map the abbreviations in the test data to the correct ones we have in our training data.
#
#
# 1. **Team Name Standardization**: Mapping team abbreviations to consistent formats.
#    ```python
#    TEAM_MAPPINGS = {
#        'CHO': 'CHA',  # Charlotte Hornets
#        'NOP': 'NOK',  # New Orleans Pelicans/Oklahoma City
#        'NOH': 'NOK',  # New Orleans Hornets/Oklahoma City
#        'NJN': 'BRK',  # New Jersey/Brooklyn Nets
#        'SEA': 'OKC',  # Seattle Supersonics/Oklahoma City
#    }
#    ```
#
# 2. **Player Ordering**: Sorting players in each lineup to ensure consistent input format
#    ```python
#    def sort_players(row):
#        home_players = sorted([row[f'home_{i}'] for i in range(5)])
#        away_players = sorted([row[f'away_{i}'] for i in range(5)])
#        for i in range(5):
#            row[f'home_{i}'] = home_players[i]
#            row[f'away_{i}'] = away_players[i]
#        return row
#    ```
#
# 3. **Label Encoding**: Converting categorical variables to numerical values
#    ```python
#    player_encoder = LabelEncoder()
#    team_encoder = LabelEncoder()
#    season_encoder = LabelEncoder()
#    ```
#
# 4. **Roster Building**: Creating team rosters for each season
#    ```python
#    rosters_dict = create_rosters(df, test_df)
#    ```
#
# ### Postprocessing Steps
#
# 1. **Candidate Filtering**: Only considering players from the appropriate team roster
#    ```python
#    eligible_players = rosters_dict.get(key, set())
#    eligible_players = eligible_players - set(home_players_4)
#    ```
#
# 2. **Probability Ranking**: Ranking candidate players by predicted probability
#    ```python
#    probs = model.predict_proba(all_candidates)[:, 1]
#    top_k_indices = np.argsort(probs)[-k:][::-1]
#    top_k_players = [valid_candidates[i] for i in top_k_indices]
#    ```
#
# 3. **Multiple Suggestions**: Providing top-k predictions rather than a single prediction
#    ```python
#    top_k_players = predict_fifth_player(
#        case['home_team'],
#        case['season'],
#        case['home_players_4'],
#        case['away_players_5'],
#        k_max
#    )
#    ```
#
# ## Evaluation
#
# We evaluated our model using Top-1 and Top-3 accuracy metrics:

# %%
def evaluate_accuracy(test_cases, k_max=3):
    # Dictionary to store results
    k_results = {}
    for k in [1, 3]:
        k_results[k] = defaultdict(list)
    
    # Process each test case
    for case in test_cases:
        top_k_players = predict_fifth_player(
            case['home_team'],
            case['season'],
            case['home_players_4'],
            case['away_players_5'],
            k_max
        )
        
        # Evaluate for k=1 and k=3
        for k in [1, 3]:
            success = False
            if top_k_players:
                success = case['true_fifth_player'] in top_k_players[:k]
            k_results[k][case['season']].append(success)
        
        # Print case details
        print(f"Test Case: {case['home_team']} vs. {case['away_team']} ({case['season']})")
        print(f"True Fifth Player: {case['true_fifth_player']}")
        print(f"Top {k_max} Predicted Players: {top_k_players}")
        
        # Print success for each k value
        for k in [1, 3]:
            success = False
            if top_k_players:
                success = case['true_fifth_player'] in top_k_players[:k]
            print(f"Top-{k} Success: {success}")
    
    # Print overall accuracy summary
    for k in [1, 3]:
        print(f"\n===== Top-{k} Accuracy =====")
        
        # Calculate overall accuracy
        all_results = []
        for season, results in k_results[k].items():
            all_results.extend(results)
        overall_accuracy = np.mean(all_results)
        print(f"Overall Top-{k} Accuracy: {overall_accuracy:.2f}")
        
        # Calculate per-season accuracy
        print(f"\nSeason-wise Top-{k} Accuracy:")
        for season in sorted(k_results[k].keys()):
            acc = np.mean(k_results[k][season])
            print(f"Season {season}: {acc:.2f}")

# %% [markdown]
# <b>Our Results:<b>
# <br>
# <img src="other/Accuracy Results.png" width="200" height="100">

# %% [markdown]
# **Evaluation metrics:**
# 1. **Top-1 Accuracy**: Percentage of cases where the true player was the top prediction
# 2. **Top-3 Accuracy**: Percentage of cases where the true player was among the top 3 predictions
#
# Our model shows strong performance on test data from 2007-2015 but has lower accuracy on 2016 data, which was not in the training set. This indicates a potential issue with generalization to new seasons, but also the impact of limited features. As many new players enter the league and change teams, it is difficult for our model to make accurate predictions on the new data, which it hasn't been trained on. If we were allowed to use more features/columns from the data (such as player/team statistics), we believe this would be much improved.
#
# ## Challenges and Future Work
#
# ### Challenges
#
# 1. **Accuracy for 2016 test data**: The model performs poorly on 2016 data.
# 2. **Team name inconsistencies**: Different data sources use different team abbreviations, requiring standardization.
# 3. **Player roster changes**: Players change teams between seasons, requiring careful roster management.
#
# ### Future Work
#
# 1. **Incorporate additional features**: Player statistics, position information, and playing time could improve predictions.
# 2. **Alternative models**: Experiment with neural networks or ensemble methods.
# 3. **Time-based features**: Create features that capture lineup changes over time.
# 4. **Optimization for specific game situations**: Consider score, time remaining, and game context.
#
# ## Conclusion
#
# Our NBA fifth player prediction model demonstrates the potential of machine learning in sports analytics. While it performs well on historical data, there's room for improvement in generalizing to new seasons. This project provides a foundation for further exploration in lineup optimization and player prediction in basketball.

# %% [markdown]
# # Run Our Code:
# Execute the below cell to run our project and view the model's accuracy results.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import os, joblib, numpy as np
from collections import defaultdict
import time

# Cache for loaded model and encoders
model_cache = {}
encoder_cache = {}

# To standardize team abbreviations in the test data  
TEAM_MAPPINGS = {
    'CHO': 'CHA',  	# Charlotte Hornets
    'NOP': 'NOK',  	# New Orleans Pelicans/Oklahoma City
    'NOH': 'NOK',   # New Orleans Hornets/Oklahoma City
    'NJN': 'BRK',	# New Jersey/Brooklyn Nets
    'SEA': 'OKC',	# Seattle Supersonics/Oklahoma City
}

# ------------- LOADING & PROCESSING DATA ------------- # 
# Function to load and preprocess the training data
def load_data(data_dir):
    all_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.csv')]
    df_list = []

    for file in all_files:  # Append all csv files into one dataframe to be used later
        df = pd.read_csv(file)
        df_list.append(df)
    df = pd.concat(df_list, ignore_index=True)
    
    # Function to sort players. Original training data has no order, 
    # so this ensures the model doesn't try to learn patterns that don't exist
    def sort_players(row):
        home_players = sorted([row[f'home_{i}'] for i in range(5)])
        away_players = sorted([row[f'away_{i}'] for i in range(5)])
        for i in range(5):
            row[f'home_{i}'] = home_players[i]
            row[f'away_{i}'] = away_players[i]
        return row
    
    df = df.apply(sort_players, axis=1)
    
    return df

# Function to create lists of eligible players
def create_rosters(train_df, test_df=None):
    # Create a roster for each home team and season from training data
    # ex. (GSW, 2010) is one roster, all players that were on GSW in 2010. Separate for each year
    roster = train_df.groupby(['home_team', 'season'])[[f'home_{i}' for i in range(5)]].apply(
        lambda x: set(pd.unique(x.values.ravel()))
    ).to_dict()
    
    # Check away lineups to make sure that rosters are complete
    for idx, row in train_df.iterrows():
        key = (row['away_team'], row['season'])
        if key not in roster:
            roster[key] = set()
        for i in range(5):
            roster[key].add(row[f'away_{i}'])
    
    # To build 2016 rosters (new season in the test data)
    if test_df is not None:
        train_seasons = set(train_df['season'].unique())
        test_seasons = set(test_df['season'].unique())
        new_seasons = test_seasons - train_seasons
        
        if new_seasons:
            print(f"Building rosters of eligible players for new seasons in test data: {new_seasons}")
            
            new_season_df = test_df[test_df['season'].isin(new_seasons)]
            
            # Build rosters for new season from test data
            for idx, row in new_season_df.iterrows():
                # Add home team players
                key = (row['home_team'], row['season'])
                if key not in roster:
                    roster[key] = set()
                for i in range(5):
                    player = row[f'home_{i}']
                    if player != '?':  # Skip unknown players
                        roster[key].add(player)
                
                # Add away team players
                key = (row['away_team'], row['season'])
                if key not in roster:
                    roster[key] = set()
                for i in range(5):
                    roster[key].add(row[f'away_{i}'])
                    
            # Add the true fifth player to the roster (from labels file)
            if 'true_fifth_player' in new_season_df.columns:
                for idx, row in new_season_df.iterrows():
                    key = (row['home_team'], row['season'])
                    if key in roster and row['true_fifth_player'] != '?':
                        roster[key].add(row['true_fifth_player'])
    return roster

# Function to encode all categorical features to numerical values (needed for use in Random Forest) 
def encode_features(df, player_encoder, team_encoder, season_encoder):
    df['home_team_encoded'] = team_encoder.transform(df['home_team'])
    df['away_team_encoded'] = team_encoder.transform(df['away_team'])
    df['season_encoded'] = season_encoder.transform(df['season'])
    for i in range(5):
        df[f'home_{i}_encoded'] = player_encoder.transform(df[f'home_{i}'])
        df[f'away_{i}_encoded'] = player_encoder.transform(df[f'away_{i}'])
    return df

# Function to load model and encoders with caching (reduce running time)
def load_model_and_encoders():
    if 'player_encoder' not in encoder_cache:
        encoder_cache['player_encoder'] = joblib.load('saved_files/player_encoder.pkl')
        encoder_cache['team_encoder'] = joblib.load('saved_files/team_encoder.pkl')
        encoder_cache['season_encoder'] = joblib.load('saved_files/season_encoder.pkl')
    
    if 'model' not in model_cache:
        model_cache['model'] = joblib.load('saved_files/nba_lineup_model.pkl')
    
    return (
        model_cache['model'],
        encoder_cache['player_encoder'],
        encoder_cache['team_encoder'],
        encoder_cache['season_encoder']
    )


# ------------- PREDICTION, TESTING, ACCURACY ------------- #
# Prediction function, returns top 'k' options for missing 5th player from the data.
def predict_fifth_player(home_team, season, home_players_4, away_players_5, k):
    # Load encoders and model
    model, player_encoder, team_encoder, season_encoder = load_model_and_encoders()
    
    # Get the eligible players for home team and season of input case
    key = (home_team, season)
    eligible_players = rosters_dict.get(key, set())
    
    if not eligible_players:
        print(f"Warning: No roster found for {home_team} in season {season}")
        return None
    
    # Remove the 4 players already in the lineup from eligible players
    eligible_players = eligible_players - set(home_players_4)
    eligible_players = list(eligible_players)
    
    # Try to encode the home team and season values of input case for use in model
    try:
        home_team_enc = team_encoder.transform([home_team])[0]
    except ValueError:
        print(f"Unknown home team: {home_team}")
        return None
    try:
        season_enc = season_encoder.transform([season])[0]
    except ValueError:
        print(f"Unknown season: {season}")
        return None
    
    # Encode away players
    away_encoded = []
    for p in away_players_5:
        try:
            encoded_p = player_encoder.transform([p])[0]
        except ValueError:
            print(f"Unknown away player: {p}, using default encoding")
            encoded_p = -1  # Default for unknown player
        away_encoded.append(encoded_p)
    
    feature_rows = []
    valid_candidates = []
    
    # Loop through and evaluate the winning prob. of all eligible players
    for candidate in eligible_players:
        try:
            # Create and encode home lineup with the current eligible player
            home_lineup = sorted(home_players_4 + [candidate])
            home_encoded = []
            valid_player = True
            for p in home_lineup:
                try:
                    encoded_p = player_encoder.transform([p])[0]
                except ValueError:
                    valid_player = False
                    break
                home_encoded.append(encoded_p)
            
            if not valid_player:
                continue
                
            # Prepare features
            features = [home_team_enc, season_enc] + home_encoded + away_encoded
            feature_rows.append(features)
            valid_candidates.append(candidate)
            
        except Exception:
            continue
    
    if not valid_candidates:
        print(f"No valid candidates found for {home_team} in season {season}")
        return None
    
    # Define features and columns, get model to make predictions
    features_array = np.array(feature_rows)
    columns = ['home_team_encoded', 'season_encoded',
                  'home_0_encoded', 'home_1_encoded', 'home_2_encoded', 
                  'home_3_encoded', 'home_4_encoded',
                  'away_0_encoded', 'away_1_encoded', 'away_2_encoded', 
                  'away_3_encoded', 'away_4_encoded']
    
    # Create dataframe with the defined features and columns for use in the model
    all_candidates = pd.DataFrame(features_array, columns=columns)
    probs = model.predict_proba(all_candidates)[:, 1] # Use model to predict probability of each candidate being the actual fifth player
        
    # Return the top-k players with highest probabilities
    top_k_indices = np.argsort(probs)[-k:][::-1]
    top_k_players = [valid_candidates[i] for i in top_k_indices]
        
    return top_k_players

# Function to automatically generate test cases
def process_test_cases(test_file, labels_file):
    test_df = pd.read_csv(test_file)
    labels_df = pd.read_csv(labels_file)
    
    # Combine the true labels into test DataFrame
    test_df['true_fifth_player'] = labels_df['removed_value']
    
    # Fix team names in test data
    test_df['home_team'] = test_df['home_team'].replace(TEAM_MAPPINGS)
    test_df['away_team'] = test_df['away_team'].replace(TEAM_MAPPINGS)

    test_cases = []
    for _, row in test_df.iterrows():
        # Extract home players and find missing position
        home_players = [row[f'home_{i}'] for i in range(5)]
        missing_idx = [i for i, player in enumerate(home_players) if player == '?'][0]
        
        # Get sorted known home and away players (to ensure consistency with training data)
        home_players_4 = sorted([p for i, p in enumerate(home_players) if i != missing_idx])
        away_players_5 = sorted([row[f'away_{i}'] for i in range(5)])
        
        test_cases.append({
            'home_team': row['home_team'],
            'away_team': row['away_team'],
            'season': row['season'],
            'home_players_4': home_players_4,
            'away_players_5': away_players_5,
            'true_fifth_player': row['true_fifth_player']
        })
    return test_cases

# Function to evaluate accuracy (evaluates both top-1 and top-3 accuracy)
def evaluate_accuracy(test_cases, k_max=3):
    # Dictionary to store results for both k values
    k_results = {}
    for k in [1, 3]:
        k_results[k] = defaultdict(list)
    
    # Pass each test case to the prediction function
    for case in test_cases:
        top_k_players = predict_fifth_player(
            case['home_team'],
            case['season'],
            case['home_players_4'],
            case['away_players_5'],
            k_max
        )
        
        # Evaluate success for k=1 and k=3, based on if the actual player shows up in the model's predictions
        for k in [1, 3]:
            success = False
            if top_k_players:
                success = case['true_fifth_player'] in top_k_players[:k]
            
            k_results[k][case['season']].append(success)
        
        # Print information for each test case
        print(f"Test Case: {case['home_team']} vs. {case['away_team']} ({case['season']})")
        print(f"Home Players (4): {case['home_players_4']}")
        print(f"Away Players (5): {case['away_players_5']}")
        print(f"True Fifth Player: {case['true_fifth_player']}")
        print(f"Top {k_max} Predicted Players: {top_k_players}")
        
        for k in [1, 3]:
            success = False
            if top_k_players:
                success = case['true_fifth_player'] in top_k_players[:k]
            print(f"Top-{k} Success: {success}")
        
        print("-" * 50)
    
    # Print overall accuracy summary by season for k=1 and k=3
    for k in [1, 3]:
        print(f"\n===== Top-{k} Accuracy =====")
        
        # Calculate overall accuracy
        all_results = []
        for season, results in k_results[k].items():
            all_results.extend(results)
        overall_accuracy = np.mean(all_results)
        print(f"Overall Top-{k} Accuracy: {overall_accuracy:.2f}")
        
        # Calculate per-season accuracy
        print(f"\nSeason-wise Top-{k} Accuracy:")
        for season in sorted(k_results[k].keys()):
            acc = np.mean(k_results[k][season])
            print(f"Season {season}: {acc:.2f}")


# ------------- MAIN CODE ------------- #
if __name__ == '__main__':
    start_time = time.time()

    # Create the encoders directory if it doesn't exist
    os.makedirs('encoders', exist_ok=True)

    # Check if model and encoders already exist
    models_exist = (
        os.path.exists('saved_files/nba_lineup_model.pkl') and
        os.path.exists('saved_files/player_encoder.pkl') and
        os.path.exists('saved_files/team_encoder.pkl') and
        os.path.exists('saved_files/season_encoder.pkl')
    )

    if not models_exist:
        print("Model doesn't exist. Training new model...")
        
        # Load and process training data
        data_dir = './training_files'
        df = load_data(data_dir)
        
        # Load test data for roster creation
        test_file = 'test_files/NBA_test.csv'
        labels_file = 'test_files/NBA_test_labels.csv'
        test_df = pd.read_csv(test_file)
        labels_df = pd.read_csv(labels_file)
        
        # Fix team names in test data
        test_df['home_team'] = test_df['home_team'].replace(TEAM_MAPPINGS)
        test_df['away_team'] = test_df['away_team'].replace(TEAM_MAPPINGS)
        
        # Combine the true labels into test DataFrame
        test_df['true_fifth_player'] = labels_df['removed_value']
        
        # Create rosters from training data and add rosters for new season (2016) from test data
        rosters_dict = create_rosters(df, test_df)
        
        # Save rosters for future use
        joblib.dump(rosters_dict, 'saved_files/rosters_dict.pkl')
        
        # Initialize encoders
        player_encoder = LabelEncoder()
        team_encoder = LabelEncoder()
        season_encoder = LabelEncoder()
        
        # Get all unique values from data for encoding
        all_players_train = pd.unique(df[[f'home_{i}' for i in range(5)] + [f'away_{i}' for i in range(5)]].values.ravel())
        all_players_test = pd.unique(test_df[[f'home_{i}' for i in range(5)] + [f'away_{i}' for i in range(5)]].values.ravel())
        all_players_test = np.append(all_players_test, labels_df['removed_value'].values)
        all_players = np.unique(np.concatenate([all_players_train, all_players_test]))
        all_players = all_players[all_players != '?']  # Remove placeholder
        
        teams_train = pd.unique(pd.concat([df['home_team'], df['away_team']]))
        teams_test = pd.unique(pd.concat([test_df['home_team'], test_df['away_team']]))
        teams = np.unique(np.concatenate([teams_train, teams_test]))
        
        seasons_train = pd.unique(df['season'])
        seasons_test = pd.unique(test_df['season'])
        seasons = np.unique(np.concatenate([seasons_train, seasons_test]))
        
        # Fit encoders on all data (including test data) to ensure we can encode all values
        player_encoder.fit(all_players)
        team_encoder.fit(teams)
        season_encoder.fit(seasons)
        
        # Add encoded versions of each column to the training dataframe only
        df = encode_features(df, player_encoder, team_encoder, season_encoder)
                
        # ------------- TRAINING MODEL ------------- #
        X = df[['home_team_encoded', 'season_encoded', 
            'home_0_encoded', 'home_1_encoded', 'home_2_encoded', 'home_3_encoded', 'home_4_encoded',
            'away_0_encoded', 'away_1_encoded', 'away_2_encoded', 'away_3_encoded', 'away_4_encoded']]
        y = df['outcome']
        
        # Create weights based on recency
        df['weight'] = df['season'].apply(lambda x: 1 + 0.2 * max(0, x - 2010))  # More weight to recent seasons

        # Train Random Forest Classifier
        model = RandomForestClassifier(n_estimators=500, max_depth=None, random_state=1, n_jobs=-1)
        model.fit(X, y, sample_weight=df['weight'])
        
        # Save model and encoders
        joblib.dump(model, 'saved_files/nba_lineup_model.pkl')
        joblib.dump(player_encoder, 'saved_files/player_encoder.pkl')
        joblib.dump(team_encoder, 'saved_files/team_encoder.pkl')
        joblib.dump(season_encoder, 'saved_files/season_encoder.pkl')
        
        print("Model trained and saved successfully.")
    else:
        print("Model already exists. Loading saved model.")

    # Load the roster dictionary
    if os.path.exists('saved_files/rosters_dict.pkl'):
        rosters_dict = joblib.load('saved_files/rosters_dict.pkl')
    else:
        print("Rosters don't exist. Creating rosters...")
        data_dir = './training_files'
        df = load_data(data_dir)
        
        test_file = 'test_files/NBA_test.csv'
        labels_file = 'test_files/NBA_test_labels.csv'
        test_df = pd.read_csv(test_file)
        labels_df = pd.read_csv(labels_file)
        
        # Fix team names in test data
        test_df['home_team'] = test_df['home_team'].replace(TEAM_MAPPINGS)
        test_df['away_team'] = test_df['away_team'].replace(TEAM_MAPPINGS)
        
        # Combine the true labels into test DataFrame
        test_df['true_fifth_player'] = labels_df['removed_value']
        
        # Create rosters
        rosters_dict = create_rosters(df, test_df)
        
        # Save rosters for future use
        joblib.dump(rosters_dict, 'saved_files/rosters_dict.pkl')

    # ------------- TESTING MODEL ------------- #
    # Process test cases from test data
    test_file = 'test_files/NBA_test.csv'
    labels_file = 'test_files/NBA_test_labels.csv'
    test_cases = process_test_cases(test_file, labels_file)
    evaluate_accuracy(test_cases)

    end_time = time.time()
    elapsed_time_minutes = (end_time - start_time) / 60
    print(f"Total execution time: {elapsed_time_minutes:.2f} minutes")
# Out:
# Model already exists. Loading saved model.
# Test Case: IND vs. BOS (2007)
# Home Players (4): ['Danny Granger', 'Darrell Armstrong', 'Keith McLeod', 'Mike Dunleavy']
# Away Players (5): ['Allan Ray', 'Gerald Green', 'Kendrick Perkins', 'Ryan Gomes', 'Sebastian Telfair']
# True Fifth Player: Troy Murphy
# Top 3 Predicted Players: ['Troy Murphy', 'Stephen Jackson', 'Shawne Williams']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: HOU vs. DAL (2007)
# Home Players (4): ['Bonzi Wells', 'Juwan Howard', 'Luther Head', 'Tracy McGrady']
# Away Players (5): ['Austin Croshere', 'Erick Dampier', 'Greg Buckner', 'Jason Terry', 'Josh Howard']
# True Fifth Player: Chuck Hayes
# Top 3 Predicted Players: ['Chuck Hayes', 'Dikembe Mutombo', 'Jake Tsakalidis']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: SAS vs. POR (2007)
# Home Players (4): ['Beno Udrih', 'Bruce Bowen', 'Matt Bonner', 'Tim Duncan']
# Away Players (5): ['Brandon Roy', 'Jamaal Magloire', 'Jarrett Jack', 'Juan Dixon', 'Zach Randolph']
# True Fifth Player: Brent Barry
# Top 3 Predicted Players: ['Brent Barry', 'James White', 'Michael Finley']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIN vs. BOS (2007)
# Home Players (4): ['Kevin Garnett', 'Randy Foye', 'Ricky Davis', 'Trenton Hassell']
# Away Players (5): ['Al Jefferson', 'Brian Scalabrine', 'Delonte West', 'Paul Pierce', 'Ryan Gomes']
# True Fifth Player: Craig Smith
# Top 3 Predicted Players: ['Craig Smith', 'Eddie Griffin', 'Bracey Wright']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MEM vs. LAL (2007)
# Home Players (4): ['Chucky Atkins', 'Hakim Warrick', 'Mike Miller', 'Rudy Gay']
# Away Players (5): ['Andrew Bynum', 'Kobe Bryant', 'Lamar Odom', 'Luke Walton', 'Smush Parker']
# True Fifth Player: Stromile Swift
# Top 3 Predicted Players: ['Stromile Swift', 'Tarence Kinsey', 'Scott Padgett']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIL vs. CLE (2007)
# Home Players (4): ['Andrew Bogut', 'Brian Skinner', 'Michael Redd', 'Mo Williams']
# Away Players (5): ['Anderson Varejao', 'Drew Gooden', 'Eric Snow', 'Larry Hughes', 'LeBron James']
# True Fifth Player: Charlie Bell
# Top 3 Predicted Players: ['Charlie Bell', 'Charlie Villanueva', 'Chris McCray']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIA vs. GSW (2007)
# Home Players (4): ['Antoine Walker', 'James Posey', 'Jason Kapono', 'Udonis Haslem']
# Away Players (5): ['Andris Biedrins', 'Jason Richardson', 'Matt Barnes', 'Mike Dunleavy', 'Monta Ellis']
# True Fifth Player: Dwyane Wade
# Top 3 Predicted Players: ['Dwyane Wade', 'Jason Williams', 'Earl Barron']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CLE vs. SAC (2007)
# Home Players (4): ['Eric Snow', 'Larry Hughes', 'Sasha Pavlovic', 'Zydrunas Ilgauskas']
# Away Players (5): ['Corliss Williamson', 'Francisco Garcia', 'John Salmons', 'Kevin Martin', 'Shareef Abdur-Rahim']
# True Fifth Player: Anderson Varejao
# Top 3 Predicted Players: ['Anderson Varejao', 'Damon Jones', 'Daniel Gibson']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: GSW vs

# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIA vs. NYK (2007)
# Home Players (4): ['Alonzo Mourning', 'Dwyane Wade', 'Gary Payton', 'Udonis Haslem']
# Away Players (5): ['Channing Frye', 'Eddy Curry', 'Jamal Crawford', 'Quentin Richardson', 'Stephon Marbury']
# True Fifth Player: Antoine Walker
# Top 3 Predicted Players: ['Antoine Walker', 'Dorell Wright', 'Earl Barron']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: NYK vs. SAS (2007)
# Home Players (4): ['David Lee', 'Malik Rose', 'Mardy Collins', 'Nate Robinson']
# Away Players (5): ['Brent Barry', 'Bruce Bowen', 'Michael Finley', 'Tim Duncan', 'Tony Parker']
# True Fifth Player: Quentin Richardson
# Top 3 Predicted Players: ['Quentin Richardson', 'Randolph Morris', 'Renaldo Balkman']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: NYK vs. ORL (2007)
# Home Players (4): ['Eddy Curry', 'Jared Jeffries', 'Mardy Collins', 'Stephon Marbury']
# Away Players (5): ['Darko Milicic', 'Dwight Howard', 'J.J. Redick', 'Keyon Dooling', 'Trevor Ariza']
# True Fifth Player: Renaldo Balkman
# Top 3 Predicted Players: ['Renaldo Balkman', 'Randolph Morris', 'Nate Robinson']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DEN vs. LAC (2007)
# Home Players (4): ['Andre Miller', 'Joe Smith', 'Reggie Evans', 'Yakhouba Diawara']
# Away Players (5): ['Corey Maggette', 'Cuttino Mobley', 'Daniel Ewing', 'James Singleton', 'Tim Thomas']
# True Fifth Player: J.R. Smith
# Top 3 Predicted Players: ['J.R. Smith', 'Jamal Sampson', 'Earl Boykins']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DEN vs. SAC (2007)
# Home Players (4): ['Carmelo Anthony', 'J.R. Smith', 'Linas Kleiza', 'Marcus Camby']
# Away Players (5): ['Brad Miller', 'Kevin Martin', 'Metta World Peace', 'Mike Bibby', 'Shareef Abdur-Rahim']
# True Fifth Player: Allen Iverson
# Top 3 Predicted Players: ['Allen Iverson', 'Andre Miller', 'Anthony Carter']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: LAL vs. DEN (2007)
# Home Players (4): ['Jordan Farmar', 'Ronny Turiaf', 'Sasha Vujacic', 'Vladimir Radmanovic']
# Away Players (5): ['Allen Iverson', 'Earl Boykins', 'Marcus Camby', 'Reggie Evans', 'Yakhouba Diawara']
# True Fifth Player: Maurice Evans
# Top 3 Predicted Players: ['Maurice Evans', 'Luke Walton', 'Lamar Odom']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: NYK vs. PHI (2007)
# Home Players (4): ['Channing Frye', 'Eddy Curry', 'Jared Jeffries', 'Quentin Richardson']
# Away Players (5): ['Andre Iguodala', 'Andre Miller', 'Kyle Korver', 'Samuel Dalembert', 'Willie Green']
# True Fifth Player: Stephon Marbury
# Top 3 Predicted Players: ['Stephon Marbury', 'Steve Francis', 'Randolph Morris']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: GSW vs. PHI (2007)
# Home Players (4): ['Andris Biedrins', 'Baron Davis', 'Jason Richardson', 'Mike Dunleavy']
# Away Players (5): ['Andre Miller', 'Kevin Ollie', 'Kyle Korver', 'Rodney Carney', 'Samuel Dalembert']
# True Fifth Player: Matt Barnes
# Top 3 Predicted Players: ['Matt Barnes', 'Mickael Pietrus', 'Monta Ellis']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case

# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DEN vs. UTA (2007)
# Home Players (4): ['Allen Iverson', 'Earl Boykins', 'Reggie Evans', 'Yakhouba Diawara']
# Away Players (5): ['Dee Brown', 'Derek Fisher', 'Jarron Collins', 'Matt Harpring', 'Paul Millsap']
# True Fifth Player: Jamal Sampson
# Top 3 Predicted Players: ['Jamal Sampson', 'J.R. Smith', 'DerMarr Johnson']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: BOS vs. CHA (2007)
# Home Players (4): ['Paul Pierce', 'Ryan Gomes', 'Theo Ratliff', 'Wally Szczerbiak']
# Away Players (5): ['Brevin Knight', 'Emeka Okafor', 'Gerald Wallace', 'Jake Voskuhl', 'Raymond Felton']
# True Fifth Player: Sebastian Telfair
# Top 3 Predicted Players: ['Sebastian Telfair', 'Tony Allen', 'Rajon Rondo']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DEN vs. CLE (2007)
# Home Players (4): ['J.R. Smith', 'Nene Hilario', 'Steve Blake', 'Yakhouba Diawara']
# Away Players (5): ['Daniel Gibson', 'Drew Gooden', 'Larry Hughes', 'LeBron James', 'Zydrunas Ilgauskas']
# True Fifth Player: Marcus Camby
# Top 3 Predicted Players: ['Marcus Camby', 'Eduardo Najera', 'Earl Boykins']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: SAC vs. DEN (2007)
# Home Players (4): ['Brad Miller', 'John Salmons', 'Kevin Martin', 'Metta World Peace']
# Away Players (5): ['Allen Iverson', 'Carmelo Anthony', 'Linas Kleiza', 'Marcus Camby', 'Steve Blake']
# True Fifth Player: Francisco Garcia
# Top 3 Predicted Players: ['Francisco Garcia', 'Jason Hart', 'Corliss Williamson']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: WAS vs. DAL (2007)
# Home Players (4): ['Antawn Jamison', 'Caron Butler', 'DeShawn Stevenson', 'Etan Thomas']
# Away Players (5): ['Devin Harris', 'Dirk Nowitzki', 'Erick Dampier', 'Jason Terry', 'Josh Howard']
# True Fifth Player: Gilbert Arenas
# Top 3 Predicted Players: ['Gilbert Arenas', 'James Lang', 'Jarvis Hayes']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: SAS vs. SAC (2007)
# Home Players (4): ['Bruce Bowen', 'Fabricio Oberto', 'Jacque Vaughn', 'Michael Finley']
# Away Players (5): ['Francisco Garcia', 'John Salmons', 'Justin Williams', 'Kevin Martin', 'Ronnie Price']
# True Fifth Player: Manu Ginobili
# Top 3 Predicted Players: ['Manu Ginobili', 'Brent Barry', 'Robert Horry']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: PHO vs. DAL (2007)
# Home Players (4): ["Amar'e Stoudemire", 'Leandro Barbosa', 'Raja Bell', 'Shawn Marion']
# Away Players (5): ['Devean George', 'Dirk Nowitzki', 'Jason Terry', 'Jerry Stackhouse', 'Josh Howard']
# True Fifth Player: Steve Nash
# Top 3 Predicted Players: ['Steve Nash', 'Sean Marks', 'Kurt Thomas']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: WAS vs. DET (2007)
# Home Players (4): ['Antonio Daniels', 'Etan Thomas', 'Gilbert Arenas', 'Jarvis Hayes']
# Away Players (5): ['Antonio McDyess', 'Carlos Delfino', 'Chauncey Billups', 'Chris Webber', 'Lindsey Hunter']
# True Fifth Player: Caron Butler
# Top 3 Predicted Players: ['Caron Butler', 'Calvin Booth', 'Brendan Haywood']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. BRK (2007)
# Home Players (4): ['Chris Duhon', 'Kirk Hinrich', 'Malik Allen', 'Thabo Sefolosha']
# Away Players (5): ['Antoine Wright', 'Bostjan Nachbar', 'Hassan Adams', 'Josh Boone', 'Marcus Williams']
# True Fifth Player: Ben Gordon
# Top 3 Predicted Players: ['Ben Gordon', 'Ben Wallace', 'Luol Deng']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DET vs. NYK (2007)
# Home Players (4): ['Chauncey Billups', 'Richard Hamilton', 'Ronald Murray', 'Tayshaun Prince']
# Away Players (5): ['Eddy Curry', 'Jamal Crawford', 'Quentin Richardson', 'Stephon Marbury', 'Steve Francis']
# True Fifth Player: Carlos Delfino
# Top 3 Predicted Players: ['Carlos Delfino', 'Nazr Mohammed', 'Lindsey Hunter']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIL vs. MEM (2007)
# Home Players (4): ['Charlie Bell', 'Charlie Villanueva', 'Dan Gadzuric', 'Steve Blake']
# Away Players (5): ['Brian Cardinal', 'Damon Stoudamire', 'Hakim Warrick', 'Rudy Gay', 'Tarence Kinsey']
# True Fifth Player: David Noel
# Top 3 Predicted Players: ['David Noel', 'Damir Markota', 'Earl Boykins']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: HOU vs. SAS (2007)
# Home Players (4): ['John Lucas III', 'Kirk Snyder', 'Steve Novak', 'Vassilis Spanoulis']
# Away Players (5): ['Beno Udrih', 'Fabricio Oberto', 'Jacque Vaughn', 'Matt Bonner', 'Melvin Ely']
# True Fifth Player: Jake Tsakalidis
# Top 3 Predicted Players: ['Jake Tsakalidis', 'Dikembe Mutombo', 'Juwan Howard']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: PHO vs. CHI (2007)
# Home Players (4): ['James Jones', 'Leandro Barbosa', 'Raja Bell', 'Shawn Marion']
# Away Players (5): ['Ben Gordon', 'Ben Wallace', 'Chris Duhon', 'Kirk Hinrich', 'Luol Deng']
# True Fifth Player: Amar'e Stoudemire
# Top 3 Predicted Players: ["Amar'e Stoudemire", 'Boris Diaw', 'Eric Piatkowski']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: LAC vs. MEM (2007)
# Home Players (4): ['Corey Maggette', 'Elton Brand', 'Quinton Ross', 'Tim Thomas']
# Away Players (5): ['Chucky Atkins', 'Dahntay Jones', 'Hakim Warrick', 'Lawrence Roberts', 'Mike Miller']
# True Fifth Player: Sam Cassell
# Top 3 Predicted Players: ['Sam Cassell', 'Paul Davis', 'Luke Jackson']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: LAC vs. DAL (2007)
# Home Players (4): ['Cuttino Mobley', 'Elton Brand', 'Quinton Ross', 'Sam Cassell']
# Away Players (5): ['Anthony Johnson', 'Dirk Nowitzki', 'Erick Dampier', 'Jason Terry', 'Jerry Stackhouse']
# True Fifth Player: Shaun Livingston
# Top 3 Predicted Players: ['Shaun Livingston', 'Tim Thomas', 'Paul Davis']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: UTA vs. CLE (2007)
# Home Players (4): ['Derek Fisher', 'Matt Harpring', 'Mehmet Okur', 'Paul Millsap']
# Away Players (5): ['Anderson Varejao', 'Donyell Marshall', 'Eric Snow', 'LeBron James', 'Sasha Pavlovic']
# True Fifth Player: Gordan Giricek
# Top 3 Predicted Players: ['Gordan Giricek', 'Jarron Collins', 'Carlos Boozer']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. MEM (2007)
# Home Players (4): ['Ben Gordon', 'Kirk Hinrich', 'Luol Deng', 'Viktor Khryapa']
# Away Players (5): ['Chucky Atkins', 'Dahntay Jones', 'Hakim Warrick', 'Lawrence Roberts', 'Mike Miller']
# True Fifth Player: Mike Sweetney
# Top 3 Predicted Players: ['Mike Sweetney', 'P.J. Brown', 'Malik Allen']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: GSW vs. UTA (2007)
# Home Players (4): ['Al Harrington', 'Baron Davis', 'Matt Barnes', 'Monta Ellis']
# Away Players (5): ['Carlos Boozer', 'Derek Fisher', 'Deron Williams', 'Matt Harpring', 'Mehmet Okur']
# True Fifth Player: Stephen Jackson
# Top 3 Predicted Players: ['Stephen Jackson', 'Jason Richardson', 'Andris Biedrins']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: LAL vs. GSW (2007)
# Home Players (4): ['Kobe Bryant', 'Lamar Odom', 'Ronny Turiaf', 'Sasha Vujacic']
# Away Players (5): ['Al Harrington', 'Andris Biedrins', 'Baron Davis', 'Monta Ellis', 'Stephen Jackson']
# True Fifth Player: Shammond Williams
# Top 3 Predicted Players: ['Shammond Williams', 'Luke Walton', 'Smush Parker']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DEN vs. ATL (2007)
# Home Players (4): ['Andre Miller', 'Carmelo Anthony', 'Eduardo Najera', 'Linas Kleiza']
# Away Players (5): ['Joe Johnson', 'Josh Smith', 'Lorenzen Wright', 'Salim Stoudamire', 'Tyronn Lue']
# True Fifth Player: Earl Boykins
# Top 3 Predicted Players: ['Earl Boykins', 'DerMarr Johnson', 'J.R. Smith']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: NYK vs. PHO (2007)
# Home Players (4): ['David Lee', 'Eddy Curry', 'Jamal Crawford', 'Renaldo Balkman']
# Away Players (5): ['Boris Diaw', 'James Jones', 'Jumaine Jones', 'Leandro Barbosa', 'Raja Bell']
# True Fifth Player: Nate Robinson
# Top 3 Predicted Players: ['Nate Robinson', 'Quentin Richardson', 'Randolph Morris']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: NYK vs. TOR (2007)
# Home Players (4): ['Channing Frye', 'Jared Jeffries', 'Nate Robinson', 'Renaldo Balkman']
# Away Players (5): ['Andrea Bargnani', 'Chris Bosh', 'Joey Graham', 'Juan Dixon', 'T.J. Ford']
# True Fifth Player: Steve Francis
# Top 3 Predicted Players: ['Steve Francis', 'Stephon Marbury', 'Quentin Richardson']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: ATL vs. UTA (2007)
# Home Players (4): ['Joe Johnson', 'Salim Stoudamire', 'Shelden Williams', 'Speedy Claxton']
# Away Players (5): ['Carlos Boozer', 'Deron Williams', 'Gordan Giricek', 'Matt Harpring', 'Mehmet Okur']
# True Fifth Player: Josh Smith
# Top 3 Predicted Players: ['Josh Smith', 'Lorenzen Wright', 'Josh Childress']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIL vs. SAC (2007)
# Home Players (4): ['Andrew Bogut', 'Michael Redd', 'Mo Williams', 'Ruben Patterson']
# Away Players (5): ['John Salmons', 'Kenny Thomas', 'Kevin Martin', 'Mike Bibby', 'Shareef Abdur-Rahim']
# True Fifth Player: Charlie Villanueva
# Top 3 Predicted Players: ['Charlie Villanueva', 'Charlie Bell', 'Brian Skinner']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: BOS vs. ATL (2007)
# Home Players (4): ['Delonte West', 'Gerald Green', 'Kendrick Perkins', 'Ryan Gomes']
# Away Players (5): ['Joe Johnson', 'Josh Childress', 'Marvin Williams', 'Shelden Williams', 'Zaza Pachulia']
# True Fifth Player: Rajon Rondo
# Top 3 Predicted Players: ['Rajon Rondo', 'Paul Pierce', 'Michael Olowokandi']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: ATL vs. MIL (2007)
# Home Players (4): ['Josh Childress', 'Salim Stoudamire', 'Shelden Williams', 'Tyronn Lue']
# Away Players (5): ['Andrew Bogut', 'Charlie Bell', 'Ersan Ilyasova', 'Michael Redd', 'Steve Blake']
# True Fifth Player: Lorenzen Wright
# Top 3 Predicted Players: ['Lorenzen Wright', 'Marvin Williams', 'Matt Freije']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: IND vs. LAC (2007)
# Home Players (4): ['Jamaal Tinsley', "Jermaine O'Neal", 'Mike Dunleavy', 'Troy Murphy']
# Away Players (5): ['Chris Kaman', 'Corey Maggette', 'Cuttino Mobley', 'Elton Brand', 'Shaun Livingston']
# True Fifth Player: Danny Granger
# Top 3 Predicted Players: ['Danny Granger', 'Darrell Armstrong', 'David Harrison']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. BRK (2007)
# Home Players (4): ['Andres Nocioni', 'Chris Duhon', 'Kirk Hinrich', 'P.J. Brown']
# Away Players (5): ['Bostjan Nachbar', 'Jason Kidd', 'Mikki Moore', 'Richard Jefferson', 'Vince Carter']
# True Fifth Player: Ben Gordon
# Top 3 Predicted Players: ['Ben Gordon', 'Ben Wallace', 'Luol Deng']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CLE vs. IND (2007)
# Home Players (4): ['Anderson Varejao', 'Donyell Marshall', 'LeBron James', 'Shannon Brown']
# Away Players (5): ['Darrell Armstrong', 'Ike Diogu', 'Jeff Foster', 'Mike Dunleavy', 'Orien Greene']
# True Fifth Player: Eric Snow
# Top 3 Predicted Players: ['Eric Snow', 'Drew Gooden', 'Dwayne Jones']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: BOS vs. CLE (2007)
# Home Players (4): ['Al Jefferson', 'Kendrick Perkins', 'Rajon Rondo', 'Ryan Gomes']
# Away Players (5): ['Anderson Varejao', 'Eric Snow', 'Sasha Pavlovic', 'Shannon Brown', 'Zydrunas Ilgauskas']
# True Fifth Player: Gerald Green
# Top 3 Predicted Players: ['Gerald Green', 'Delonte West', 'Brian Scalabrine']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: NYK vs. BOS (2007)
# Home Players (4): ['Jared Jeffries', 'Malik Rose', 'Nate Robinson', 'Stephon Marbury']
# Away Players (5): ['Brian Scalabrine', 'Delonte West', 'Gerald Green', 'Leon Powe', 'Rajon Rondo']
# True Fifth Player: David Lee
# Top 3 Predicted Players: ['David Lee', 'Eddy Curry', 'Jamal Crawford']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: POR vs. ORL (2007)
# Home Players (4): ['Jamaal Magloire', 'LaMarcus Aldridge', 'Sergio Rodriguez', 'Travis Outlaw']
# Away Players (5): ['Carlos Arroyo', 'Darko Milicic', 'Dwight Howard', 'Hedo Turkoglu', 'Keyon Dooling']
# True Fifth Player: Juan Dixon
# Top 3 Predicted Players: ['Juan Dixon', 'Joel Przybilla', 'Luke Schenscher']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIA vs. SAC (2007)
# Home Players (4): ['Antoine Walker', 'Eddie Jones', 'James Posey', 'Jason Williams']
# Away Players (5): ['Brad Miller', 'Kevin Martin', 'Metta World Peace', 'Mike Bibby', 'Shareef Abdur-Rahim']
# True Fifth Player: Shaquille O'Neal
# Top 3 Predicted Players: ['Alonzo Mourning', "Shaquille O'Neal", 'Robert Hite']
# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: LAL vs. PHO (2007)
# Home Players (4): ['Brian Cook', 'Lamar Odom', 'Sasha Vujacic', 'Vladimir Radmanovic']
# Away Players (5): ['Boris Diaw', 'James Jones', 'Kurt Thomas', 'Leandro Barbosa', 'Marcus Banks']
# True Fifth Player: Jordan Farmar
# Top 3 Predicted Players: ['Jordan Farmar', 'Kobe Bryant', 'Kwame Brown']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. MEM (2007)
# Home Players (4): ['Ben Gordon', 'Chris Duhon', 'Kirk Hinrich', 'Mike Sweetney']
# Away Players (5): ['Chucky Atkins', 'Lawrence Roberts', 'Mike Miller', 'Pau Gasol', 'Rudy Gay']
# True Fifth Player: Luol Deng
# Top 3 Predicted Players: ['Luol Deng', 'Malik Allen', 'Viktor Khryapa']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIN vs. LAC (2007)
# Home Players (4): ['Bracey Wright', 'Craig Smith', 'Kevin Garnett', 'Randy Foye']
# Away Players (5): ['Elton Brand', 'Quinton Ross', 'Sam Cassell', 'Shaun Livingston', 'Tim Thomas']
# True Fifth Player: Ricky Davis
# Top 3 Predicted Players: ['Ricky Davis', 'Rashad McCants', 'Troy Hudson']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: GSW vs. MIN (2007)
# Home Players (4): ['Baron Davis', 'Jason Richardson', 'Mickael Pietrus', 'Stephen Jackson']
# Away Players (5): ['Craig Smith', 'Kevin Garnett', 'Randy Foye', 'Rashad McCants', 'Ricky Davis']
# True Fifth Player: Andris Biedrins
# Top 3 Predicted Players: ['Andris Biedrins', 'Al Harrington', 'Adonal Foyle']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: PHI vs. DET (2007)
# Home Players (4): ['Alan Henderson', 'Andre Iguodala', 'Andre Miller', 'Willie Green']
# Away Players (5): ['Carlos Delfino', 'Dale Davis', 'Rasheed Wallace', 'Ronald Murray', 'Will Blalock']
# True Fifth Player: Samuel Dalembert
# Top 3 Predicted Players: ['Shavlik Randolph', 'Samuel Dalembert', 'Steven Hunter']
# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. CHA (2007)
# Home Players (4): ['Andres Nocioni', 'Ben Gordon', 'Kirk Hinrich', 'Tyrus Thomas']
# Away Players (5): ['Alan Anderson', 'Emeka Okafor', 'Jeff McInnis', 'Raymond Felton', 'Walter Herrmann']
# True Fifth Player: P.J. Brown
# Top 3 Predicted Players: ['P.J. Brown', 'Mike Sweetney', 'Malik Allen']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: GSW vs. MEM (2007)
# Home Players (4): ['Andris Biedrins', 'Jason Richardson', 'Monta Ellis', 'Stephen Jackson']
# Away Players (5): ['Hakim Warrick', 'Junior Harrington', 'Pau Gasol', 'Rudy Gay', 'Tarence Kinsey']
# True Fifth Player: Matt Barnes
# Top 3 Predicted Players: ['Matt Barnes', 'Mickael Pietrus', 'Mike Dunleavy']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. POR (2007)
# Home Players (4): ['Adrian Griffin', 'Ben Wallace', 'Luol Deng', 'Thabo Sefolosha']
# Away Players (5): ['Fred Jones', 'Ime Udoka', 'Jamaal Magloire', 'Sergio Rodriguez', 'Travis Outlaw']
# True Fifth Player: Chris Duhon
# Top 3 Predicted Players: ['Chris Duhon', 'Ben Gordon', 'Andres Nocioni']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIN vs. DEN (2007)
# Home Players (4): ['Craig Smith', 'Kevin Garnett', 'Rashad McCants', 'Ricky Davis']
# Away Players (5): ['Carmelo Anthony', 'J.R. Smith', 'Marcus Camby', 'Nene Hilario', 'Steve Blake']
# True Fifth Player: Randy Foye
# Top 3 Predicted Players: ['Randy Foye', 'Troy Hudson', 'Trenton Hassell']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: UTA vs. TOR (2007)
# Home Players (4): ['Derek Fisher', 'Deron Williams', 'Jarron Collins', 'Paul Millsap']
# Away Players (5): ['Andrea Bargnani', 'Fred Jones', 'Jorge Garbajosa', 'Jose Calderon', 'Morris Peterson']
# True Fifth Player: Matt Harpring
# Top 3 Predicted Players: ['Matt Harpring', 'Lou Amundson', 'Mehmet Okur']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: GSW vs. ATL (2007)
# Home Players (4): ['Al Harrington', 'Andris Biedrins', 'Matt Barnes', 'Sarunas Jasikevicius']
# Away Players (5): ['Joe Johnson', 'Josh Childress', 'Josh Smith', 'Marvin Williams', 'Zaza Pachulia']
# True Fifth Player: Stephen Jackson
# Top 3 Predicted Players: ['Stephen Jackson', 'Renaldo Major', 'Troy Murphy']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. NOK (2008)
# Home Players (4): ['Aaron Gray', 'Chris Duhon', 'Joakim Noah', 'Thabo Sefolosha']
# Away Players (5): ['Bobby Jackson', 'Hilton Armstrong', 'Jannero Pargo', 'Ryan Bowen', 'Tyson Chandler']
# True Fifth Player: Tyrus Thomas
# Top 3 Predicted Players: ['Tyrus Thomas', 'Viktor Khryapa', 'Thomas Gardner']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: LAL vs. NYK (2008)
# Home Players (4): ['Kobe Bryant', 'Kwame Brown', 'Lamar Odom', 'Ronny Turiaf']
# Away Players (5): ['David Lee', 'Jamal Crawford', 'Mardy Collins', 'Quentin Richardson', 'Zach Randolph']
# True Fifth Player: Derek Fisher
# Top 3 Predicted Players: ['Derek Fisher', 'Didier Ilunga-Mbenga', 'Coby Karl']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: MIL vs. MEM (2008)
# Home Players (4): ['Andrew Bogut', 'Michael Redd', 'Mo Williams', 'Yi Jianlian']
# Away Players (5): ['Damon Stoudamire', 'Darko Milicic', 'Mike Miller', 'Pau Gasol', 'Rudy Gay']
# True Fifth Player: Desmond Mason
# Top 3 Predicted Players: ['Desmond Mason', 'Dan Gadzuric', 'Jake Voskuhl']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DEN vs. HOU (2008)
# Home Players (4): ['Allen Iverson', 'Carmelo Anthony', 'Eduardo Najera', 'J.R. Smith']
# Away Players (5): ['Carl Landry', 'Luis Scola', 'Rafer Alston', 'Steve Novak', 'Tracy McGrady']
# True Fifth Player: Kenyon Martin
# Top 3 Predicted Players: ['Kenyon Martin', 'Jelani McCoy', 'Linas Kleiza']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: PHO vs. DEN (2008)
# Home Players (4): ['Boris Diaw', 'Marcus Banks', 'Shawn Marion', 'Steve Nash']
# Away Players (5): ['Allen Iverson', 'Anthony Carter', 'Eduardo Najera', 'Linas Kleiza', 'Nene Hilario']
# True Fifth Player: Amar'e Stoudemire
# Top 3 Predicted Players: ["Amar'e Stoudemire", 'Alando Tucker', 'Brian Skinner']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: POR vs. SAC (2008)
# Home Players (4): ['Brandon Roy', 'Martell Webster', 'Steve Blake', 'Travis Outlaw']
# Away Players (5): ['Beno Udrih', 'Brad Miller', 'Francisco Garcia', 'Kevin Martin', 'Shelden Williams']
# True Fifth Player: LaMarcus Aldridge
# Top 3 Predicted Players: ['LaMarcus Aldridge', 'Josh McRoberts', 'Joel Przybilla']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: UTA vs. LAL (2008)
# Home Players (4): ['C.J. Miles', 'Deron Williams', 'Jason Hart', 'Paul Millsap']
# Away Players (5): ['Andrew Bynum', 'Jordan Farmar', 'Kobe Bryant', 'Lamar Odom', 'Sasha Vujacic']
# True Fifth Player: Andrei Kirilenko
# Top 3 Predicted Players: ['Andrei Kirilenko', 'Ronnie Brewer', 'Ronnie Price']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DEN vs. MIL (2008)
# Home Players (4): ['Allen Iverson', 'Chucky Atkins', 'Eduardo Najera', 'Linas Kleiza']
# Away Players (5): ['Andrew Bogut', 'Michael Redd', 'Mo Williams', 'Royal Ivey', 'Yi Jianlian']
# True Fifth Player: Nene Hilario
# Top 3 Predicted Players: ['Nene Hilario', 'Mike Wilks', 'Marcus Camby']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CLE vs. PHI (2008)
# Home Players (4): ['Anderson Varejao', 'Larry Hughes', 'LeBron James', 'Sasha Pavlovic']
# Away Players (5): ['Kyle Korver', 'Lou Williams', 'Reggie Evans', 'Samuel Dalembert', 'Thaddeus Young']
# True Fifth Player: Drew Gooden
# Top 3 Predicted Players: ['Drew Gooden', 'Dwayne Jones', 'Donyell Marshall']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: TOR vs. IND (2008)
# Home Players (4): ['Carlos Delfino', 'Jason Kapono', 'Jose Calderon', 'Kris Humphries']
# Away Players (5): ['Danny Granger', 'Jamaal Tinsley', "Jermaine O'Neal", 'Mike Dunleavy', 'Troy Murphy']
# True Fifth Player: Jorge Garbajosa
# Top 3 Predicted Players: ['Jorge Garbajosa', 'Linton Johnson', 'Juan Dixon']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DET vs. DAL (2008)
# Home Players (4): ['Jarvis Hayes', 'Jason Maxiell', 'Richard Hamilton', 'Rodney Stuckey']
# Away Players (5): ['Brandon Bass', 'Erick Dampier', 'Jason Terry', 'Josh Howard', 'Trenton Hassell']
# True Fifth Player: Antonio McDyess
# Top 3 Predicted Players: ['Antonio McDyess', 'Arron Afflalo', 'Cheikh Samb']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: GSW vs. SAS (2008)
# Home Players (4): ['Andris Biedrins', 'Baron Davis', 'Mickael Pietrus', 'Stephen Jackson']
# Away Players (5): ['Bruce Bowen', 'Manu Ginobili', 'Michael Finley', 'Tim Duncan', 'Tony Parker']
# True Fifth Player: Monta Ellis
# Top 3 Predicted Players: ['Monta Ellis', "Patrick O'Bryant", 'Kelenna Azubuike']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: POR vs. CLE (2008)
# Home Players (4): ['James Jones', 'Joel Przybilla', 'Sergio Rodriguez', 'Travis Outlaw']
# Away Players (5): ['Damon Jones', 'Daniel Gibson', 'Devin Brown', 'LeBron James', 'Zydrunas Ilgauskas']
# True Fifth Player: Steve Blake
# Top 3 Predicted Players: ['Steve Blake', 'Taurean Green', 'Von Wafer']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case

# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CHI vs. TOR (2016)
# Home Players (4): ['Bobby Portis', 'Derrick Rose', 'Doug McDermott', 'Tony Snell']
# Away Players (5): ['Cory Joseph', 'DeMar DeRozan', 'Jonas Valanciunas', 'Luis Scola', 'Terrence Ross']
# True Fifth Player: Pau Gasol
# Top 3 Predicted Players: ['Jimmy Butler', 'Kirk Hinrich', 'Joakim Noah']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
# Test Case: CHI vs. HOU (2016)
# Home Players (4): ['Derrick Rose', 'Jimmy Butler', 'Mike Dunleavy', 'Taj Gibson']
# Away Players (5): ['Donatas Motiejunas', 'Dwight Howard', 'James Harden', 'Patrick Beverley', 'Trevor Ariza']
# True Fifth Player: Pau Gasol
# Top 3 Predicted Players: ['Tony Snell', 'Bobby Portis', 'Doug McDermott']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
# Test Case: MIA vs. DET (2016)
# Home Players (4): ['Beno Udrih', 'Hassan Whiteside', 'Justise Winslow', 'Luol Deng']
# Away Players (5): ['Aron Baynes', 'Ersan Ilyasova', 'Marcus Morris', 'Reggie Jackson', 'Stanley Johnson']
# True Fifth Player: Dwyane Wade
# Top 3 Predicted Players: ['Dwyane Wade', 'Goran Dragic', 'Gerald Green']
# Top-1 Success: True
# Top-3 Success: True
# --------------------------------------------------
# Test Case: BOS vs. CHA (2016)
# Home Players (4): ['James Young', 'Jonas Jerebko', 'Terry Rozier', 'Tyler Zeller']
# Away Players (5): ['Al Jefferson', 'Courtney Lee', 'Jeremy Lin', 'Kemba Walker', 'Marvin Williams']
# True Fifth Player: R.J. Hunter
# Top 3 Predicted Players: ['Avery Bradley', 'R.J. Hunter', 'Marcus Smart']
# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: CLE vs. CHI (2016)
# Home Players (4): ['Iman Shumpert', 'Kyrie Irving', 'Mo Williams', 'Tristan Thompson']
# Away Players (5): ['Bobby Portis', 'Derrick Rose', 'Doug McDermott', 'Jimmy Butler', 'Nikola Mirotic']
# True Fifth Player: Kevin Love
# Top 3 Predicted Players: ['James Jones', 'Jared Cunningham', 'J.R. Smith']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
# Test Case: CHA vs. PHO (2016)
# Home Players (4): ['Al Jefferson', 'Jeremy Lamb', 'Jeremy Lin', 'Kemba Walker']
# Away Players (5): ['Archie Goodwin', 'Devin Booker', 'Jon Leuer', 'Mirza Teletovic', 'Phil Pressey']
# True Fifth Player: Frank Kaminsky
# Top 3 Predicted Players: ['P.J. Hairston', 'Nicolas Batum', 'Marvin Williams']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
# Test Case: IND vs. BRK (2016)
# Home Players (4): ['C.J. Miles', 'Ian Mahinmi', 'Paul George', 'Rodney Stuckey']
# Away Players (5): ['Bojan Bogdanovic', 'Brook Lopez', 'Jarrett Jack', 'Joe Johnson', 'Thaddeus Young']
# True Fifth Player: Monta Ellis
# Top 3 Predicted Players: ['Solomon Hill', 'Ty Lawson', 'Myles Turner']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
# Test Case: MIN vs. PHO (2016)
# Home Players (4): ['Greg Smith', 'Shabazz Muhammad', 'Tayshaun Prince', 'Tyus Jones']
# Away Players (5): ['Alex Len', 'Brandon Knight', 'Jon Leuer', 'P.J. Tucker', 'Ronnie Price']
# True Fifth Player: Nemanja Bjelica
# Top 3 Predicted Players: ['Zach LaVine', 'Andrew Wiggins', 'Ricky Rubio']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
# Test Case: BRK vs. CHA (2016)
# Home Players (4): ['Joe Johnson', 'Thaddeus Young', 'Wayne Ellington', 'Willie Reed']
# Away Players (5): ['Al Jefferson', 'Courtney Lee', 'Kemba Walker', 'Marvin Williams', 'Nicolas Batum']
# True Fifth Player: Donald Sloan
# Top 3 Predicted Players: ['Thomas Robinson', 'Sean Kilpatrick', 'Sergey Karasev']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
# Test Case: TOR vs. CHA (2016)
# Home Players (4): ['DeMar DeRozan', 'DeMarre Carroll', 'Kyle Lowry', 'Luis Scola']
# Away Players (5): ['Frank Kaminsky', 'Jeremy Lamb', 'Kemba Walker', 'Marvin Williams', 'Nicolas Batum']
# True Fifth Player: Jonas Valanciunas
# Top 3 Predicted Players: ['Patrick Patterson', 'Jonas Valanciunas', 'Jason Thompson']
# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: DAL vs. DET (2016)
# Home Players (4): ['David Lee', 'Dirk Nowitzki', 'J.J. Barea', 'Raymond Felton']
# Away Players (5): ['Aron Baynes', 'Kentavious Caldwell-Pope', 'Reggie Bullock', 'Steve Blake', 'Tobias Harris']
# True Fifth Player: Devin Harris
# Top 3 Predicted Players: ['Chandler Parsons', 'Deron Williams', 'Devin Harris']
# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: NOK vs. ORL (2016)
# Home Players (4): ['Anthony Davis', 'Eric Gordon', 'Jrue Holiday', 'Ryan Anderson']
# Away Players (5): ['C.J. Watson', 'Evan Fournier', 'Jason Smith', 'Nikola Vucevic', 'Victor Oladipo']
# True Fifth Player: Ish Smith
# Top 3 Predicted Players: ['Kendrick Perkins', 'Dante Cunningham', 'Ish Smith']
# Top-1 Success: False
# Top-3 Success: True
# --------------------------------------------------
# Test Case: BRK vs. NYK (2016)
# Home Players (4): ['Brook Lopez', 'Donald Sloan', 'Joe Johnson', 'Thaddeus Young']
# Away Players (5): ['Arron Afflalo', 'Carmelo Anthony', 'Jose Calderon', 'Kristaps Porzingis', 'Robin Lopez']
# True Fifth Player: Wayne Ellington
# Top 3 Predicted Players: ['Chris McCullough', 'Jarrett Jack', 'Markel Brown']
# Top-1 Success: False
# Top-3 Success: False
# --------------------------------------------------
#
# ===== Top-1 Accuracy =====
# Overall Top-1 Accuracy: 0.83
#
# Season-wise Top-1 Accuracy:
# Season 2007: 0.95
# Season 2008: 0.91
# Season 2009: 0.91
# Season 2010: 0.93
# Season 2011: 0.95
# Season 2012: 0.87
# Season 2013: 0.87
# Season 2014: 0.85
# Season 2015: 0.94
# Season 2016: 0.17
#
# ===== Top-3 Accuracy =====
# Overall Top-3 Accuracy: 0.91
#
# Season-wise Top-3 Accuracy:
# Season 2007: 0.99
# Season 2008: 0.97
# Season 2009: 0.97
# Season 2010: 0.95
# Season 2011: 0.97
# Season 2012: 0.95
# Season 2013: 0.97
# Season 2014: 0.92
# Season 2015: 0.95
# Season 2016: 0.49
# Total execution time: 1.97 minutes
